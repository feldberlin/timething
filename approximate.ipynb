# %%
import sys
sys.path.append('src')

# %%
from pathlib import Path
import typing

from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

from timething import dataset, job, text, utils, align  # type: ignore

metadata = Path("/Users/purzelrakete/src/scratch/keanu/text.csv")
cfg = utils.load_config("english")
ds = dataset.SpeechDataset(Path(metadata), cfg.sampling_rate)
device = "cpu"
aligner = align.Aligner.build(device, cfg)
loader = DataLoader(
    ds,
    batch_size=1,
    num_workers=1,
    collate_fn=dataset.collate_fn,
    shuffle=False,
)

# %%
batch = next(iter(loader))

# %%
xs, ys, ys_original, ids = batch
xs.shape
# Out:
# torch.Size([1, 1, 26759040])

# %%
offset = (16000*60*10)
duration = (16000*30)
window = xs[:, :, offset:(offset+duration)]
window
# Out:
# tensor([[[-3.5329e-05, -6.2365e-05,  2.2021e-05,  ..., -1.3205e-01,
#           -1.5090e-01, -1.6871e-01]]])

# %%
ipd.Audio(window.squeeze(), rate=cfg.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
logprobs = aligner.logp(window)
logprobs
# Out:
# /usr/local/Caskroom/miniforge/base/envs/timething/lib/python3.9/site-packages/transformers-4.4.2-py3.8.egg/transformers/models/wav2vec2/modeling_wav2vec2.py:704: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
# tensor([[[-5.8443e-04, -2.5318e+01, -2.5248e+01,  ..., -1.5519e+01,
#           -1.2485e+01, -1.4603e+01],
#          [-5.5550e-05, -3.0979e+01, -3.1144e+01,  ..., -1.7851e+01,
#           -1.6716e+01, -1.7544e+01],
#          [-1.2131e-03, -2.6593e+01, -2.6581e+01,  ..., -1.5895e+01,
#           -1.3523e+01, -1.4987e+01],
#          ...,
#          [-2.9542e-02, -2.1105e+01, -2.1053e+01,  ..., -1.3409e+01,
#           -1.0146e+01, -1.3352e+01],
#          [-5.0626e+00, -1.9250e+01, -1.9189e+01,  ..., -1.2708e+01,
#           -9.8022e+00, -1.3852e+01],
#          [-6.1057e-01, -1.9205e+01, -1.9169e+01,  ..., -1.2520e+01,
#           -4.9877e+00, -1.3373e+01]]])

# %%
transcript
# Out:
# "<pad>|pr<pad>o<pad>c<pad>es<pad>s<pad>i<pad>n<pad>g<pad>|<pad>o<pad>r<pad>|<pad>t<pad>e<pad>x<pad>t<pad>|<pad>s<pad>t<pad>il<pad>l<pad>|<pad>pr<pad>o<pad>c<pad>e<pad>s<pad>s<pad>i<pad>n<pad>g<pad>|<pad>t<pad>o<pad>|<pad>f<pad>i<pad>ve<pad>-hund<pad>r<pad>ed<pad>|f<pad>i<pad>ve<pad>-h<pad>un<pad>d<pad>r<pad>e<pad>d<pad>|<pad>a<pad>l<pad>e<pad>x<pad>|p<pad>a<pad>p<pad>a<pad>d<pad>e<pad>m<pad>u<pad>s<pad>|<pad>you've|writen|a|b<pad>o<pad>o<pad>k<pad>y<pad>e<pad>|<pad>h<pad>ow<pad>|<pad>a<pad>b<pad>o<pad>u<pad>t|<pad>th<pad>a<pad>t<pad>it<pad>'s|<pad>c<pad>a<pad>l<pad>l<pad>e<pad>d<pad>|<pad>k<pad>i<pad>a<pad>n<pad>a<pad>r<pad>e<pad>v<pad>'s|m<pad>o<pad>s<pad>t<pad>|t<pad>r<pad>i<pad>u<pad>m<pad>ph<pad>a<pad>n<pad>t<pad>|<pad>t<pad>he<pad>|<pad>m<pad>o<pad>v<pad>i<pad>e<pad>s<pad>|<pad>an<pad>d<pad>|<pad>m<pad>e<pad>a<pad>n<pad>i<pad>n<pad>g<pad>|<pad>o<pad>f<pad>|an|<pad>i<pad>r<pad>r<pad>e<pad>p<pad>re<pad>s<pad>s<pad>i<pad>b<pad>le<pad>|<pad>i<pad>c<pad>o<pad>n<pad>b<pad>ut<pad>|i|have<pad>|a|<pad>qu<pad>est<pad>ion<pad>|f<pad>or<pad>|y<pad>o<pad>u<pad>|<pad>i<pad>s<pad>|<pad>i<pad>t<pad>|<pad>p<pad>o<pad>s<pad>s<pad>i<pad>b<pad>l<pad>e<pad>|<pad>t<pad>o<pad>|<pad>e<pad>v<pad>e<pad>n<pad>|<pad>g<pad>e<pad>t<pad>|<pad>n<pad>e<pad>a<pad>r<pad>|<pad>the<pad>|b<pad>o<pad>t<pad>t<pad>o<pad>m<pad>|<pad>o<pad>f<pad>|<pad>k<pad>i<pad>o<pad>n<pad>a<pad>r<pad>e<pad>ve<pad>s<pad>i<pad>|<pad>thi<pad>nk|<pad>h<pad>e<pad>|<pad>m<pad>i<pad>ght<pad>|b<pad>e<pad>|an|<pad>u<pad>n<pad>k<pad>n<pad>o<pad>w<pad>a<pad>b<pad>le|<pad>i<pad>c<pad>o<pad>n<pad>|<pad>s<pad>i<pad>t|b<pad>e<pad>f<pad>o<pad>re|y<pad>ou<pad>|s<pad>om<pad>e<pad>one|who<pad>'s|th<pad>ought|ab<pad>out|hi<pad>m<pad>|<pad>f<pad>or<pad>|<pad>l<pad>ke<pad>|a|<pad>who<pad>l<pad>e<pad>|<pad>y<pad>ea<pad>r<pad>|<pad>a<pad>n<pad>d<pad>|<pad>i<pad>|d<pad>on't|kn<pad>ow|"

# %%
d = {v: k for (k, v) in aligner.vocab().items()}
x = torch.argmax(logprobs, dim=2)
tokens = [d[code.item()] for code in x.squeeze()]
transcript = ''.join(c for c, _ in itertools.groupby(tokens))
cleaned = " ".join(transcript.replace(d[0], '').split("|"))
cleaned
# Out:
# "kurt was a different kind of rock star kianoo's a different kind of rock star too andhe has a lot of big hits he has speed which sortofconfirms him like point breakers like this guy could be an action star and ten speed comes l o this guy is an action starthenhe runs in the other directioit is a very genex thing to do when confronted with the opportunity to be superfamous hdoes hamlet canadaand he's clearly unsatisf"

# %%
windows(cleaned)
# Out:
# ["kurt was a different kind of rock star kianoo's a different kind of rock star to",
#  "ianoo's a different kind of rock star too andhe has a lot of big hits he has spe",
#  'o andhe has a lot of big hits he has speed which sortofconfirms him like point b',
#  'ed which sortofconfirms him like point breakers like this guy could be an action',
#  'reakers like this guy could be an action star and ten speed comes l o this guy i',
#  ' star and ten speed comes l o this guy is an action starthenhe runs in the other',
#  's an action starthenhe runs in the other directioit is a very genex thing to do ',
#  ' directioit is a very genex thing to do when confronted with the opportunity to ',
#  'when confronted with the opportunity to be superfamous hdoes hamlet canadaand he',
#  "be superfamous hdoes hamlet canadaand he's clearly unsatisf"]

# %%
windows(ys[0])
# Out:
# ['Wesley Morris Alex Pappademas, you’ve written a book.  Alex Pappademas Yeah, how',
#  'itten a book.  Alex Pappademas Yeah, how about that?  Wesley Morris It’s called ',
#  ' about that?  Wesley Morris It’s called “Keanu Reeves: Most Triumphant: The Movi',
#  '“Keanu Reeves: Most Triumphant: The Movies and Meaning of an Irrepressible Icon.',
#  'es and Meaning of an Irrepressible Icon.”  But I have a question for you. Is it ',
#  '”  But I have a question for you. Is it possible to even get near the bottom of ',
#  'possible to even get near the bottom of Keanu Reeves?  Alex Pappademas I think h',
#  'Keanu Reeves?  Alex Pappademas I think he might be an unknowable icon. I sit bef',
#  'e might be an unknowable icon. I sit before you as someone who’s thought about h',
#  'ore you as someone who’s thought about him for a whole year, and I don’t know if',
#  'im for a whole year, and I don’t know if I know him any better than you do. But ',
#  ' I know him any better than you do. But let’s find out.  Wesley Morris Here we g',
#  'let’s find out.  Wesley Morris Here we go.  [MUSIC]  I’m Wesley Morris, and I’m ',
#  'o.  [MUSIC]  I’m Wesley Morris, and I’m a culture writer at The New York Times, ',
#  'a culture writer at The New York Times, and this is “Still Processing.” Today on',
#  'and this is “Still Processing.” Today on the show, we’re going to talk about the',
#  ' the show, we’re going to talk about the one, the only, Keanu Reeves, and we’re ',
#  ' one, the only, Keanu Reeves, and we’re going to try and figure out why we get s',
#  'going to try and figure out why we get so much out of a movie star who appears t',
#  'o much out of a movie star who appears to give us so little.  Alex, I think I ha',
#  'o give us so little.  Alex, I think I have what is probably a pretty common Kean',
#  've what is probably a pretty common Keanu Reeves experience, which is that I kin',
#  'u Reeves experience, which is that I kind of took him for granted. He’s always b',
#  'd of took him for granted. He’s always been in my life, and I just never really ',
#  'een in my life, and I just never really felt like there was much to figure out. ',
#  'felt like there was much to figure out. But who is this person, and what have I ',
#  'But who is this person, and what have I been misunderstanding if I’m thinking of',
#  'been misunderstanding if I’m thinking of him as an empty vessel?  Alex Pappadema',
#  ' him as an empty vessel?  Alex Pappademas Maybe he’s an empty vessel, and that’s',
#  's Maybe he’s an empty vessel, and that’s a possibility that we have to entertain',
#  ' a possibility that we have to entertain as part of it, I think. And I think par',
#  ' as part of it, I think. And I think part of your feeling that you can’t look ri',
#  't of your feeling that you can’t look right at him, and that he doesn’t — it’s a',
#  'ght at him, and that he doesn’t — it’s almost like your interest glances off of ',
#  'lmost like your interest glances off of him, I think it’s a valid Keanu experien',
#  'him, I think it’s a valid Keanu experience.  And I think that a lot of that gets',
#  'ce.  And I think that a lot of that gets dramatized in the work. He is always th',
#  ' dramatized in the work. He is always that guy who comes into the story and need',
#  'at guy who comes into the story and needs to be filled up. And what’s the most o',
#  's to be filled up. And what’s the most obvious metaphorical version of that?  Ar',
#  'bvious metaphorical version of that?  Archived Recording (Morpheus) The Matrix i',
#  'chived Recording (Morpheus) The Matrix is everywhere. It is all around us.  Alex',
#  's everywhere. It is all around us.  Alex Pappademas He has to get a plug put in ',
#  ' Pappademas He has to get a plug put in the back of his head, and he gets filled',
#  'the back of his head, and he gets filled up with kung fu just right in the back ',
#  ' up with kung fu just right in the back of the head.  Archived Recording (Keanu ',
#  'of the head.  Archived Recording (Keanu Reeves As Neo) I know kung fu.  Archived',
#  'Reeves As Neo) I know kung fu.  Archived Recording (Morpheus) Show me.  Alex Pap',
#  ' Recording (Morpheus) Show me.  Alex Pappademas And I feel like that’s part of t',
#  'pademas And I feel like that’s part of the thing that you are watching with Kean',
#  'he thing that you are watching with Keanu, is somebody who comes into a story wi',
#  'u, is somebody who comes into a story with nothing and has to get filled up with',
#  'th nothing and has to get filled up with ideas. And I think what I’m chasing aft',
#  ' ideas. And I think what I’m chasing after in this book is those moments when th',
#  'er in this book is those moments when the movie gets so thin that you can basica',
#  'e movie gets so thin that you can basically see right through it, and you just s',
#  'lly see right through it, and you just see Keanu — and the movie is revealed as ',
#  'ee Keanu — and the movie is revealed as an artifice that Keanu is doing somethin',
#  'an artifice that Keanu is doing something real within it.  Archived Recording (M',
#  'g real within it.  Archived Recording (Morpheus) What is real? How do you define',
#  'orpheus) What is real? How do you define real?  Wesley Morris Well, I want to go',
#  ' real?  Wesley Morris Well, I want to go back to 1991, which is about eight year',
#  ' back to 1991, which is about eight years before “The Matrix” comes out. It was ',
#  's before “The Matrix” comes out. It was the year of “Point Break,” the year of “',
#  'the year of “Point Break,” the year of “My Own Private Idaho” — two very, very d',
#  'My Own Private Idaho” — two very, very different movies that use him in not diss',
#  'ifferent movies that use him in not dissimilar ways, right?  Alex Pappademas Yea',
#  'imilar ways, right?  Alex Pappademas Yeah, because there’s three movies in ‘91. ',
#  'h, because there’s three movies in ‘91. It’s the best movie year an actor has ev',
#  'It’s the best movie year an actor has ever had, because there’s also “Bill and T',
#  'er had, because there’s also “Bill and Ted’s Bogus Journey.”  Archived Recording',
#  'ed’s Bogus Journey.”  Archived Recording (Bill And Ted) How’s it going, Bill and',
#  ' (Bill And Ted) How’s it going, Bill and Ted?  Archived Recording (Ted) We came ',
#  ' Ted?  Archived Recording (Ted) We came to help you guys in your most unfortunat',
#  'to help you guys in your most unfortunate situation.  Archived Recording (Bill) ',
#  'e situation.  Archived Recording (Bill) Yeah.  Alex Pappademas Each of them — “B',
#  'Yeah.  Alex Pappademas Each of them — “Bogus Journey,” “Point Break,” “My Own Pr',
#  'ogus Journey,” “Point Break,” “My Own Private Idaho,” each one like a platonic l',
#  'ivate Idaho,” each one like a platonic love story between two guys.  Archived Re',
#  'ove story between two guys.  Archived Recording (Patrick Swayze As Bodhi) You st',
#  'cording (Patrick Swayze As Bodhi) You still haven’t figured out what riding wave',
#  'ill haven’t figured out what riding waves is all about, have you? It’s a state o',
#  's is all about, have you? It’s a state of mind.  Wesley Morris And for anybody w',
#  'f mind.  Wesley Morris And for anybody who doesn’t know, “Point Break” is, of co',
#  'ho doesn’t know, “Point Break” is, of course, the “surfers rob a bank” movie sta',
#  'urse, the “surfers rob a bank” movie starring Keanu Reeves as an F.B.I. agent — ',
#  'rring Keanu Reeves as an F.B.I. agent —  Archived Recording (Ben Harp) Special A',
#  ' Archived Recording (Ben Harp) Special Agent Utah, are you receiving my signal? ',
#  'gent Utah, are you receiving my signal?  Archived Recording (Keanu Reeves As Joh',
#  ' Archived Recording (Keanu Reeves As Johnny Utah) Zero distortion, sir.  Wesley ',
#  'nny Utah) Zero distortion, sir.  Wesley Morris — and Patrick Swayze as the head ',
#  'Morris — and Patrick Swayze as the head of the bank robbing crew.  Archived Reco',
#  'of the bank robbing crew.  Archived Recording (Bodhi) You want the ultimate, you',
#  'rding (Bodhi) You want the ultimate, you got to be willing to pay the ultimate p',
#  ' got to be willing to pay the ultimate price.  Wesley Morris So what’s going on ',
#  'rice.  Wesley Morris So what’s going on with Keanu in this movie as far as you c',
#  'with Keanu in this movie as far as you can see? Because I have to tell you somet',
#  'an see? Because I have to tell you something, Alex. I still haven’t seen it.  Al',
#  'hing, Alex. I still haven’t seen it.  Alex Pappademas For starters, “Point Break',
#  'ex Pappademas For starters, “Point Break” is one of those movies where Keanu ent',
#  '” is one of those movies where Keanu enters into a situation, and for the purpos',
#  'ers into a situation, and for the purposes of the plot, he has to be reprogramme',
#  'es of the plot, he has to be reprogrammed.  Wesley Morris Yes.  Alex Pappademas ',
#  'd.  Wesley Morris Yes.  Alex Pappademas And the programming is him learning how ',
#  'And the programming is him learning how to be a cool guy in order to take down t',
#  'to be a cool guy in order to take down this gang of surfing bank robbers. And he',
#  'his gang of surfing bank robbers. And he is a blank slate who gets programmed fo',
#  ' is a blank slate who gets programmed for undercover purposes and then rejects t',
#  'r undercover purposes and then rejects the programming.  Archived Recording (Kea',
#  'he programming.  Archived Recording (Keanu Reeves As Johnny Utah) Bodhi, this is',
#  'nu Reeves As Johnny Utah) Bodhi, this is your [EXPLETIVE] wake-up call, man! I a',
#  ' your [EXPLETIVE] wake-up call, man! I am an F.B.I. agent!  Archived Recording (',
#  'm an F.B.I. agent!  Archived Recording (Bodhi) I know, man. Ain’t it wild?  Alex',
#  'Bodhi) I know, man. Ain’t it wild?  Alex Pappademas But it’s about somebody with',
#  ' Pappademas But it’s about somebody with a conditional identity who realizes tha',
#  ' a conditional identity who realizes that he has no actual identity of his own. ',
#  't he has no actual identity of his own.  Wesley Morris Right, yes.  Alex Pappade',
#  ' Wesley Morris Right, yes.  Alex Pappademas And that is something that you disco',
#  'mas And that is something that you discover through the Zen state of surfing, th',
#  'ver through the Zen state of surfing, through the Zen state of skydiving, throug',
#  'rough the Zen state of skydiving, through the Zen state of bank robbery. But it’',
#  'h the Zen state of bank robbery. But it’s a movie like “The Matrix” and like man',
#  's a movie like “The Matrix” and like many other iconic Keanu Reeves movies.  Wes',
#  'y other iconic Keanu Reeves movies.  Wesley Morris The best ones, this is the th',
#  'ley Morris The best ones, this is the throughline.  Alex Pappademas Yeah, it’s o',
#  'roughline.  Alex Pappademas Yeah, it’s one of the throughlines, I think, for sur',
#  'ne of the throughlines, I think, for sure. That he’s got — that somebody needs t',
#  'e. That he’s got — that somebody needs to put information into his brain.  Wesle',
#  'o put information into his brain.  Wesley Morris Right, yes.  Alex Pappademas Th',
#  'y Morris Right, yes.  Alex Pappademas That’s what I love about the ‘91 movies, i',
#  'at’s what I love about the ‘91 movies, is that they do have this symmetry. He’s ',
#  's that they do have this symmetry. He’s put in this same situation in both “Poin',
#  'put in this same situation in both “Point Break” and “Private Idaho.” The world ',
#  't Break” and “Private Idaho.” The world gets in the way of whatever love Keanu a',
#  'gets in the way of whatever love Keanu and his co-star have for one another.  We',
#  'nd his co-star have for one another.  Wesley Morris Yes.  Alex Pappademas And in',
#  'sley Morris Yes.  Alex Pappademas And in “My Own Private Idaho” there’s all of t',
#  ' “My Own Private Idaho” there’s all of these situations. They’re in this Portlan',
#  'hese situations. They’re in this Portland demimonde world of the hustlers, but i',
#  'd demimonde world of the hustlers, but it’s also a movie about Keanu deciding wh',
#  't’s also a movie about Keanu deciding whether or not he’s going to love River Ph',
#  'ether or not he’s going to love River Phoenix the way that River Phoenix thinks ',
#  'oenix the way that River Phoenix thinks that he’s in love with Keanu.  Archived ',
#  'that he’s in love with Keanu.  Archived Recording (Mike) What do I mean to you? ',
#  'Recording (Mike) What do I mean to you?  Archived Recording (Keanu Reeves As Sco',
#  ' Archived Recording (Keanu Reeves As Scott) What do you mean to me? Mike, you’re',
#  'tt) What do you mean to me? Mike, you’re my best friend.  Wesley Morris Well, I ',
#  ' my best friend.  Wesley Morris Well, I will say, this is my first true Keanu Re',
#  'will say, this is my first true Keanu Reeves movie. So my first true Keanu Reeve',
#  'eves movie. So my first true Keanu Reeves experience was Keanu Reeves as an obje',
#  's experience was Keanu Reeves as an object, right? I’m not going to say that Gus',
#  'ct, right? I’m not going to say that Gus Van Sant intended for him to be objecti',
#  ' Van Sant intended for him to be objectified. But I think as a young gay person ',
#  'fied. But I think as a young gay person in 1991 who was trying to figure out my ',
#  'in 1991 who was trying to figure out my own stuff, there’s something about River',
#  'own stuff, there’s something about River Phoenix’s evident longing for this othe',
#  ' Phoenix’s evident longing for this other very beautiful person who is very rece',
#  'r very beautiful person who is very receptive to the affection — I can remember ',
#  'ptive to the affection — I can remember watching that film and just being like, ',
#  'watching that film and just being like, I think I love Keanu Reeves too.  Archiv',
#  'I think I love Keanu Reeves too.  Archived Recording (Mikey) I could love someon',
#  'ed Recording (Mikey) I could love someone even if I wasn’t paid for it. I love y',
#  'e even if I wasn’t paid for it. I love you, and you don’t pay me.  Archived Reco',
#  'ou, and you don’t pay me.  Archived Recording (Keanu Reeves As Scott) Mike.  Arc',
#  'rding (Keanu Reeves As Scott) Mike.  Archived Recording (Mikey) I really want to',
#  'hived Recording (Mikey) I really want to kiss you, man.  Archived Recording (Kea',
#  ' kiss you, man.  Archived Recording (Keanu Reeves As Scott) All right come here,',
#  'nu Reeves As Scott) All right come here, Mike. Just sleep.  Wesley Morris I mean',
#  ' Mike. Just sleep.  Wesley Morris I mean, I am every person who has ever loved a',
#  ', I am every person who has ever loved a probably straight guy, who is curious e',
#  ' probably straight guy, who is curious enough about the attention to reciprocate',
#  'nough about the attention to reciprocate up to a point.  Alex Pappademas It’s li',
#  ' up to a point.  Alex Pappademas It’s like a series of fantasies about Keanu Ree',
#  'ke a series of fantasies about Keanu Reeves that Keanu is participating in. He’s',
#  'ves that Keanu is participating in. He’s not sure how he feels about being looke',
#  ' not sure how he feels about being looked at.  Archived Recording (Keanu Reeves ',
#  'd at.  Archived Recording (Keanu Reeves As Scott) I only have sex with a guy for',
#  'As Scott) I only have sex with a guy for money.  Archived Recording (Mikey) Yeah',
#  ' money.  Archived Recording (Mikey) Yeah, I know.  Archived Recording (Keanu Ree',
#  ', I know.  Archived Recording (Keanu Reeves As Scott) And two guys can’t love ea',
#  'ves As Scott) And two guys can’t love each other.  Archived Recording (Mikey) Ye',
#  'ch other.  Archived Recording (Mikey) Yeah.  Wesley Morris And when Keanu pushes',
#  'ah.  Wesley Morris And when Keanu pushes River Phoenix away, it just made me fee',
#  ' River Phoenix away, it just made me feel — [GROANING] two guys can love each ot',
#  'l — [GROANING] two guys can love each other! Anyway, I just have a question for ',
#  'her! Anyway, I just have a question for you, because we’re talking about Keanu i',
#  'you, because we’re talking about Keanu in the 1990s. And he’s doing different th',
#  'n the 1990s. And he’s doing different things, and he becomes these different peo',
#  'ings, and he becomes these different people to the extent that he can become a d',
#  'ple to the extent that he can become a different person, right? These different ',
#  'ifferent person, right? These different environments for Keanu’s Keanu-ness to f',
#  'environments for Keanu’s Keanu-ness to flourish is maybe the better way to put i',
#  'lourish is maybe the better way to put it.  And so let’s just go through the ‘90',
#  't.  And so let’s just go through the ‘90s movies. Let me get my little list here',
#  's movies. Let me get my little list here — Bram Stoker’s “Dracula.”  Archived Re',
#  ' — Bram Stoker’s “Dracula.”  Archived Recording (Keanu Reeves As Jonathan Harker',
#  'cording (Keanu Reeves As Jonathan Harker) Bloody wolves chasing me through some ',
#  ') Bloody wolves chasing me through some blue inferno.  Wesley Morris He’s Don Jo',
#  'blue inferno.  Wesley Morris He’s Don John in “Much Ado About Nothing,” that Ken',
#  'hn in “Much Ado About Nothing,” that Kenneth Branagh movie with Denzel and Emma ',
#  'neth Branagh movie with Denzel and Emma Thompson.  Archived Recording (Keanu Ree',
#  'Thompson.  Archived Recording (Keanu Reeves As Don John) If I had my mouth, I wo',
#  'ves As Don John) If I had my mouth, I would bite.  Wesley Morris I’m going to sk',
#  'uld bite.  Wesley Morris I’m going to skip some of these. He plays Buddha.  Arch',
#  'ip some of these. He plays Buddha.  Archived Recording (Keanu Reeves As Siddhart',
#  'ived Recording (Keanu Reeves As Siddhartha) I must see the world, Yasodhara!  We',
#  'ha) I must see the world, Yasodhara!  Wesley Morris In 1994, his biggest hit up ',
#  'sley Morris In 1994, his biggest hit up to that point: “Speed.”  Archived Record',
#  'to that point: “Speed.”  Archived Recording (Keanu Reeves As Jack Traven) 50, st',
#  'ing (Keanu Reeves As Jack Traven) 50, stay above 50!  Wesley Morris “Johnny Mnem',
#  'ay above 50!  Wesley Morris “Johnny Mnemonic,” “A Walk in the Clouds — ”  Archiv',
#  'onic,” “A Walk in the Clouds — ”  Archived Recording (Keanu Reeves As Paul Sutto',
#  'ed Recording (Keanu Reeves As Paul Sutton) Can’t imagine how I want you.  Wesley',
#  'n) Can’t imagine how I want you.  Wesley Morris “Chain Reaction,” “Feeling Minne',
#  ' Morris “Chain Reaction,” “Feeling Minnesota,” “Devil’s Advocate — ”  Archived R',
#  'sota,” “Devil’s Advocate — ”  Archived Recording (Keanu Reeves As Paul Sutton) T',
#  'ecording (Keanu Reeves As Paul Sutton) This isn’t a popularity contest, it’s a m',
#  'his isn’t a popularity contest, it’s a murder trial.  Wesley Morris And ‘99 come',
#  'urder trial.  Wesley Morris And ‘99 comes “The Matrix.”  Archived Recording (Mor',
#  's “The Matrix.”  Archived Recording (Morpheus) After this, there is no turning b',
#  'pheus) After this, there is no turning back.  Wesley Morris So, he had one of th',
#  'ack.  Wesley Morris So, he had one of the best ‘90s of anybody who was a movie s',
#  'e best ‘90s of anybody who was a movie star in the 1990s. Maybe Will Smith and J',
#  'tar in the 1990s. Maybe Will Smith and Julia Roberts and Tom Cruise did better t',
#  'ulia Roberts and Tom Cruise did better than he did. But what is the thing that’s',
#  'han he did. But what is the thing that’s happening to him during this period, an',
#  ' happening to him during this period, and what is it that he’s doing for us duri',
#  'd what is it that he’s doing for us during the ‘90s, if you can even square thos',
#  'ng the ‘90s, if you can even square those two things?  Alex Pappademas I think i',
#  'e two things?  Alex Pappademas I think it’s important that “My Own Private Idaho',
#  't’s important that “My Own Private Idaho” comes out a week after “Nevermind” by ',
#  '” comes out a week after “Nevermind” by Nirvana, a dark day for traditional masc',
#  'Nirvana, a dark day for traditional masculinity because all of those things are ',
#  'ulinity because all of those things are about to become up for grabs thanks to ‘',
#  'about to become up for grabs thanks to ‘90s figures like Kurt Cobain and Keanu R',
#  '90s figures like Kurt Cobain and Keanu Reeves, who are going to show us a differ',
#  'eeves, who are going to show us a different way of being a man. Kurt was a diffe',
#  'ent way of being a man. Kurt was a different kind of rock star.  And Keanu is a ',
#  'rent kind of rock star.  And Keanu is a different kind of rock star too. And he ',
#  'different kind of rock star too. And he has a lot of big hits. He has “Speed,” w',
#  'has a lot of big hits. He has “Speed,” which confirms him. “Point Break” is like',
#  'hich confirms him. “Point Break” is like, oh, this guy could be an action star. ',
#  ', oh, this guy could be an action star. And then “Speed” comes out, and it’s lik',
#  'And then “Speed” comes out, and it’s like, oh, this guy is an action star.  And ',
#  'e, oh, this guy is an action star.  And then he runs in the other direction. It ',
#  'then he runs in the other direction. It is a very Gen X thing to do when confron',
#  'is a very Gen X thing to do when confronted with the opportunity to be super fam',
#  'ted with the opportunity to be super famous. And he does Hamlet in Canada. And h',
#  'ous. And he does Hamlet in Canada. And he’s clearly unsatisfied doing things lik',
#  'e’s clearly unsatisfied doing things like “Speed.” As he’s doing “Speed,” he’s w',
#  'e “Speed.” As he’s doing “Speed,” he’s walking around on closed down freeway ove',
#  'alking around on closed down freeway overpasses reciting all of the dialogue fro',
#  'rpasses reciting all of the dialogue from Hamlet because he spent three years le',
#  'm Hamlet because he spent three years learning to do Hamlet.  So by the end of t',
#  'arning to do Hamlet.  So by the end of the decade, this movie comes along that s',
#  'he decade, this movie comes along that squares the circle, which is “The Matrix,',
#  'quares the circle, which is “The Matrix,” a giant hit, but it also satisfies wha',
#  '” a giant hit, but it also satisfies whatever that philosophical art film thing ',
#  'tever that philosophical art film thing is within him, because he’s ultimately a',
#  'is within him, because he’s ultimately a bookish guy from Toronto.  Wesley Morri',
#  ' bookish guy from Toronto.  Wesley Morris Right, Keanu is such an externally ori',
#  's Right, Keanu is such an externally oriented person, where all the forces seem ',
#  'ented person, where all the forces seem to be coming from outside the house, so ',
#  'to be coming from outside the house, so to speak.  [KNOCKING]  Archived Recordin',
#  'to speak.  [KNOCKING]  Archived Recording (Keanu Reeves As Neo) Who is it?  Wesl',
#  'g (Keanu Reeves As Neo) Who is it?  Wesley Morris A lot of it means that he is, ',
#  'ey Morris A lot of it means that he is, in some ways, an object for the camera. ',
#  'in some ways, an object for the camera.  Archived Recording (Morpheus) It is the',
#  ' Archived Recording (Morpheus) It is the world that has been pulled over your ey',
#  ' world that has been pulled over your eyes to blind you from the truth.  Wesley ',
#  'es to blind you from the truth.  Wesley Morris And depending on who he’s working',
#  'Morris And depending on who he’s working with, he can sometimes seem stuck.  Arc',
#  ' with, he can sometimes seem stuck.  Archived Recording (Keanu Reeves As Neo) Yo',
#  'hived Recording (Keanu Reeves As Neo) You ever have that feeling where you’re no',
#  'u ever have that feeling where you’re not sure if you’re awake or still dreaming',
#  't sure if you’re awake or still dreaming?  Wesley Morris And he seems like a man',
#  '?  Wesley Morris And he seems like a man without a style, so to speak.  Archived',
#  ' without a style, so to speak.  Archived Recording (Oracle) Do you think you are',
#  ' Recording (Oracle) Do you think you are the one?  Archived Recording (Keanu Ree',
#  ' the one?  Archived Recording (Keanu Reeves As Neo) Honestly, I don’t know.  Ale',
#  'ves As Neo) Honestly, I don’t know.  Alex Pappademas I think Keanu is operating ',
#  'x Pappademas I think Keanu is operating almost solely on the level of vibes. And',
#  'almost solely on the level of vibes. And I think that makes some people uncomfor',
#  ' I think that makes some people uncomfortable, because I often have felt this — ',
#  'table, because I often have felt this — I’m not the first person to say it, but ',
#  'I’m not the first person to say it, but Best Actor, Best Actress is often most a',
#  'Best Actor, Best Actress is often most acting.  Either you know that they are do',
#  'cting.  Either you know that they are doing something physically difficult, or a',
#  'ing something physically difficult, or a transformation that’s like, oh my god, ',
#  ' transformation that’s like, oh my god, Glenn Close doesn’t look like Glenn Clos',
#  'Glenn Close doesn’t look like Glenn Close at all in this. It’s amazing. Where di',
#  'e at all in this. It’s amazing. Where did she go, whoever it is? Keanu does not ',
#  'd she go, whoever it is? Keanu does not give you, where did he go?  Wesley Morri',
#  'give you, where did he go?  Wesley Morris No, no, he’s always there. And he’s so',
#  's No, no, he’s always there. And he’s so present. And it’s so easy to take his p',
#  ' present. And it’s so easy to take his presentness for granted and just assume t',
#  'resentness for granted and just assume that when he is being present in that way',
#  'hat when he is being present in that way, that he’s not doing anything. But he’s',
#  ', that he’s not doing anything. But he’s definitely doing something. You’ve conv',
#  ' definitely doing something. You’ve convinced me. So we’re going to take a break',
#  'inced me. So we’re going to take a break, and when we come back, Keanu plays Kea',
#  ', and when we come back, Keanu plays Keanu.  [MUSIC]  So Alex, we’re in the 2000',
#  'nu.  [MUSIC]  So Alex, we’re in the 2000s. Who is Keanu Reeves at this point?  A',
#  's. Who is Keanu Reeves at this point?  Alex Pappademas So in 2014, Keanu appears',
#  'lex Pappademas So in 2014, Keanu appears in this movie, “John Wick,” where he’s ',
#  ' in this movie, “John Wick,” where he’s a man who has lost his wife and has been',
#  'a man who has lost his wife and has been given a puppy as her last gift to him. ',
#  ' given a puppy as her last gift to him.  Archived Recording (Helen Wick) John, I',
#  ' Archived Recording (Helen Wick) John, I’m sorry I can’t be there for you, but y',
#  '’m sorry I can’t be there for you, but you still need something, someone, to lov',
#  'ou still need something, someone, to love.  Archived Recording [DOG BARKING]  Al',
#  'e.  Archived Recording [DOG BARKING]  Alex Pappademas And then he gets into a be',
#  'ex Pappademas And then he gets into a beef with some guys, and they do a terribl',
#  'ef with some guys, and they do a terrible thing.  Archived Recording (Iosef Tara',
#  'e thing.  Archived Recording (Iosef Tarasov) Oh, I love dogs.  Alex Pappademas T',
#  'sov) Oh, I love dogs.  Alex Pappademas They murder his puppy.  Archived Recordin',
#  'hey murder his puppy.  Archived Recording [DOG WHIMPERING]  Alex Pappademas And ',
#  'g [DOG WHIMPERING]  Alex Pappademas And that’s when it turns out he is not a reg',
#  'that’s when it turns out he is not a regular guy in any way. He is John Wick. He',
#  'ular guy in any way. He is John Wick. He has killed more people than you or I ha',
#  ' has killed more people than you or I have had fast food meals in our lives. And',
#  've had fast food meals in our lives. And he proceeds to slay his way through, I ',
#  ' he proceeds to slay his way through, I think it’s the Russian mob underworld in',
#  'think it’s the Russian mob underworld in this.  Wesley Morris Yes.  Alex Pappade',
#  ' this.  Wesley Morris Yes.  Alex Pappademas He’s lost his wife and his puppy, an',
#  'mas He’s lost his wife and his puppy, and he’s going to beat up henchmen about i',
#  'd he’s going to beat up henchmen about it until he feels better. And of course, ',
#  't until he feels better. And of course, he’s not going to feel better, which is ',
#  'he’s not going to feel better, which is why there is “John Wick 2” and “John Wic',
#  'why there is “John Wick 2” and “John Wick Chapter 3.”  Archived Recording [GUNSH',
#  'k Chapter 3.”  Archived Recording [GUNSHOT]  Wesley Morris To me, it’s like when',
#  'OT]  Wesley Morris To me, it’s like when the dog dies, a part of John Wick is de',
#  ' the dog dies, a part of John Wick is dead too. And the part of him, the puppy t',
#  'ad too. And the part of him, the puppy that we associate — the cuddly internet c',
#  'hat we associate — the cuddly internet creature that we associate Keanu Reeves w',
#  'reature that we associate Keanu Reeves with, if you’re so inclined to think of K',
#  'ith, if you’re so inclined to think of Keanu Reeves as a cute object — the thing',
#  'eanu Reeves as a cute object — the thing that’s thrilling about John Wick is he ',
#  ' that’s thrilling about John Wick is he is leaving the puppy. Y’all killed him. ',
#  'is leaving the puppy. Y’all killed him. He’s dead. And now I have to kill all yo',
#  'He’s dead. And now I have to kill all you people for killing that part of me.  A',
#  'u people for killing that part of me.  Alex Pappademas Yeah, I think that that’s',
#  'lex Pappademas Yeah, I think that that’s why “John Wick” works, because there’s ',
#  ' why “John Wick” works, because there’s a sense of him, Keanu, as a tragic figur',
#  'a sense of him, Keanu, as a tragic figure. But you know him as someone who has g',
#  'e. But you know him as someone who has grown up without his father in the pictur',
#  'rown up without his father in the picture. He loses River Phoenix shortly after ',
#  'e. He loses River Phoenix shortly after “Private Idaho,” dies of a drug overdose',
#  '“Private Idaho,” dies of a drug overdose. He loses a child, and then the woman h',
#  '. He loses a child, and then the woman he was going to have the child with is ki',
#  'e was going to have the child with is killed in an accident.  Wesley Morris Yes.',
#  'lled in an accident.  Wesley Morris Yes.  Alex Pappademas And “John Wick” makes ',
#  '  Alex Pappademas And “John Wick” makes use of all these things that have been a',
#  'use of all these things that have been attached to his star text.  Wesley Morris',
#  'ttached to his star text.  Wesley Morris But it also makes him meme-able in some',
#  ' But it also makes him meme-able in some way too, right? We just make these pres',
#  ' way too, right? We just make these presumptions about who he is and how he’s fe',
#  'umptions about who he is and how he’s feeling based on what little of him we see',
#  'eling based on what little of him we see off-screen.  Alex Pappademas Yeah, the ',
#  ' off-screen.  Alex Pappademas Yeah, the meme that really connects and turns him ',
#  'meme that really connects and turns him into this internet iconic figure is a pi',
#  'into this internet iconic figure is a picture of him sitting on a park bench loo',
#  'cture of him sitting on a park bench looking sad. And they put him in all these ',
#  'king sad. And they put him in all these situations, and it’s like, he’s sitting ',
#  'situations, and it’s like, he’s sitting next to Kanye, or he’s sitting next to a',
#  'next to Kanye, or he’s sitting next to a dolphin, or whatever it is.  But everyo',
#  ' dolphin, or whatever it is.  But everyone assumes that that’s a picture of him ',
#  'ne assumes that that’s a picture of him thinking about his whole entire life and',
#  'thinking about his whole entire life and thinking about every bad thing that’s e',
#  ' thinking about every bad thing that’s ever happened to him. So what happens is ',
#  'ver happened to him. So what happens is that everyone falls back in love with hi',
#  'that everyone falls back in love with him as someone who has been stoically endu',
#  'm as someone who has been stoically enduring sadness and continues to be pure of',
#  'ring sadness and continues to be pure of heart, despite all of this evidence tha',
#  ' heart, despite all of this evidence that the world is a bleak and terrible plac',
#  't the world is a bleak and terrible place.  Wesley Morris I just feel like of al',
#  'e.  Wesley Morris I just feel like of all the movie stars we have had, he’s the ',
#  'l the movie stars we have had, he’s the only one I can think of who inspires thi',
#  'only one I can think of who inspires this kind of wish fulfillment. He is not wi',
#  's kind of wish fulfillment. He is not willing to put himself in the machine, and',
#  'lling to put himself in the machine, and so as a result, in our own somewhat vio',
#  ' so as a result, in our own somewhat violently benign way, think that it’s our j',
#  'lently benign way, think that it’s our job to give him a star narrative. And I w',
#  'ob to give him a star narrative. And I wonder if it cost him something. And to t',
#  'onder if it cost him something. And to the degree that it did, I wonder what the',
#  'he degree that it did, I wonder what the cost is.  Alex Pappademas Yeah, but it’',
#  ' cost is.  Alex Pappademas Yeah, but it’s interesting to think about it, if it’s',
#  's interesting to think about it, if it’s cost him something. Because we create a',
#  ' cost him something. Because we create all these memes about him as a culture, a',
#  'll these memes about him as a culture, and that allows him to live in the Twitte',
#  'nd that allows him to live in the Twitter world, and in the Instagram world, and',
#  'r world, and in the Instagram world, and in those things without him having to d',
#  ' in those things without him having to do anything. It’s perfect.  Wesley Morris',
#  'o anything. It’s perfect.  Wesley Morris Anything, yes, yes, yes.  Alex Pappadem',
#  ' Anything, yes, yes, yes.  Alex Pappademas He doesn’t have to do it.  Wesley Mor',
#  'as He doesn’t have to do it.  Wesley Morris He was always telling us he was not ',
#  'ris He was always telling us he was not going to be the famous person that peopl',
#  'going to be the famous person that people wanted him to be. When you bring up Ku',
#  'e wanted him to be. When you bring up Kurt Cobain and Nirvana, this idea of sell',
#  'rt Cobain and Nirvana, this idea of selling out is a real thing, right? And ther',
#  'ing out is a real thing, right? And there’s all these opportunities for him to g',
#  'e’s all these opportunities for him to give a piece of his soul to the fame indu',
#  'ive a piece of his soul to the fame industrial complex, but he’s not doing that.',
#  'strial complex, but he’s not doing that. He basically said he was never going to',
#  ' He basically said he was never going to do it essentially. The work is saying, ',
#  ' do it essentially. The work is saying, I will not be doing this.  Alex Pappadem',
#  'I will not be doing this.  Alex Pappademas Yeah, because of his year of birth, h',
#  'as Yeah, because of his year of birth, he’s technically a Boomer, but he’s on th',
#  'e’s technically a Boomer, but he’s on the very far end of that.  Wesley Morris R',
#  'e very far end of that.  Wesley Morris Real Gen X vibes, baby.  Alex Pappademas ',
#  'eal Gen X vibes, baby.  Alex Pappademas Real Gen X vibes.  Wesley Morris Real Ge',
#  'Real Gen X vibes.  Wesley Morris Real Gen X vibes.  Archived Recording (Sasha Tr',
#  'n X vibes.  Archived Recording (Sasha Tran) Oh, there he is.  Alex Pappademas Bu',
#  'an) Oh, there he is.  Alex Pappademas But at this point, around the same time as',
#  't at this point, around the same time as he’s having this “John Wick” resurgence',
#  ' he’s having this “John Wick” resurgence, he shows up in “Always Be My Maybe.”  ',
#  ', he shows up in “Always Be My Maybe.”  It’s these two people. Randall Park and ',
#  'It’s these two people. Randall Park and Ali Wong are childhood friends who reuni',
#  'Ali Wong are childhood friends who reunite later in life. And then they meet aga',
#  'te later in life. And then they meet again, and they try to navigate friendship ',
#  'in, and they try to navigate friendship turning into romance.  Wesley Morris Yes',
#  'turning into romance.  Wesley Morris Yes.  Alex Pappademas They need an Asian-Am',
#  '.  Alex Pappademas They need an Asian-American love interest for Ali Wong, a riv',
#  'erican love interest for Ali Wong, a rival for Randall Park. It is important to ',
#  'al for Randall Park. It is important to the filmmakers that that guy not be just',
#  'the filmmakers that that guy not be just some hot white guy, that it not be Chri',
#  ' some hot white guy, that it not be Chris Pine or whatever, but who is also Asia',
#  's Pine or whatever, but who is also Asian-American.  Keanu, part-Chinese, fits t',
#  'n-American.  Keanu, part-Chinese, fits that bill, has never really been cast tha',
#  'hat bill, has never really been cast that way, but this is the first time. And A',
#  't way, but this is the first time. And Ali Wong has talked about it, that she al',
#  'li Wong has talked about it, that she always just saw him that way. That was the',
#  'ways just saw him that way. That was the way in her family it was spoken about, ',
#  ' way in her family it was spoken about, that Keanu Reeves is this very successfu',
#  'that Keanu Reeves is this very successful Asian-American actor. And so he goes a',
#  'l Asian-American actor. And so he goes along with it, and he’s cast as Keanu Ree',
#  'long with it, and he’s cast as Keanu Reeves.  Archived Recording (Sasha Tran) No',
#  'ves.  Archived Recording (Sasha Tran) Now I know what it feels like to be comple',
#  'w I know what it feels like to be completely starstruck.  Archived Recording (Ke',
#  'tely starstruck.  Archived Recording (Keanu Reeves) The only stars that matter a',
#  'anu Reeves) The only stars that matter are the ones you look at when you dream. ',
#  're the ones you look at when you dream.  Alex Pappademas But he’s playing a vers',
#  ' Alex Pappademas But he’s playing a version of Keanu Reeves that is maybe Keanu ',
#  'ion of Keanu Reeves that is maybe Keanu Reeves’s idea of what the egotistical ac',
#  'Reeves’s idea of what the egotistical actor version of Keanu Reeves would be lik',
#  'tor version of Keanu Reeves would be like.  Archived Recording (Keanu Reeves) A ',
#  'e.  Archived Recording (Keanu Reeves) A pleasure to meet you, Marcus.  Archived ',
#  'pleasure to meet you, Marcus.  Archived Recording (Marcus Kim) Likewise, Keanu. ',
#  'Recording (Marcus Kim) Likewise, Keanu. I love your outfit.  Archived Recording ',
#  'I love your outfit.  Archived Recording (Keanu Reeves) Oh thanks, man. Tom Ford ',
#  '(Keanu Reeves) Oh thanks, man. Tom Ford made a custom for me.  Archived Recordin',
#  'made a custom for me.  Archived Recording (Sasha Tran) Wow.  Archived Recording ',
#  'g (Sasha Tran) Wow.  Archived Recording (Marcus Kim) I didn’t know you wore glas',
#  '(Marcus Kim) I didn’t know you wore glasses.  Archived Recording (Keanu Reeves) ',
#  'ses.  Archived Recording (Keanu Reeves) I don’t, my eyes are perfect.  Alex Papp',
#  'I don’t, my eyes are perfect.  Alex Pappademas And there’s this amazing scene wh',
#  'ademas And there’s this amazing scene where he walks into the most pretentious r',
#  'ere he walks into the most pretentious restaurant on Earth and is absolutely in ',
#  'estaurant on Earth and is absolutely in his element. They’re pointing at everybo',
#  'his element. They’re pointing at everybody. It’s like he comes here every night,',
#  'dy. It’s like he comes here every night, and they just know, and they serve him ',
#  ' and they just know, and they serve him all this like very bizarre nouvelle cuis',
#  'all this like very bizarre nouvelle cuisine.  Archived Recording (Keanu Reeves) ',
#  'ine.  Archived Recording (Keanu Reeves) May I ask, do you have any dishes that p',
#  'May I ask, do you have any dishes that play with time, the concept of time?  Arc',
#  'lay with time, the concept of time?  Archived Recording (Waiter) Ah, yes, we hav',
#  'hived Recording (Waiter) Ah, yes, we have a meat —  Alex Pappademas His entrance',
#  'e a meat —  Alex Pappademas His entrance into that restaurant itself becomes a m',
#  ' into that restaurant itself becomes a meme. So now the meme Keanu cycle is feed',
#  'eme. So now the meme Keanu cycle is feeding on itself. It’s feeding into his mov',
#  'ing on itself. It’s feeding into his movie roles, and he’s being cast in that wa',
#  'ie roles, and he’s being cast in that way. And he’s game for it. He’s going alon',
#  'y. And he’s game for it. He’s going along with it, but that version of himself d',
#  'g with it, but that version of himself does not, I don’t think, contain a grain ',
#  'oes not, I don’t think, contain a grain of truth. It’s just an idea about Keanu.',
#  'of truth. It’s just an idea about Keanu.  Wesley Morris This is an example of hi',
#  '  Wesley Morris This is an example of him receiving the projection though, right',
#  'm receiving the projection though, right? He is performing the thing that he thi',
#  '? He is performing the thing that he thinks he’s been avoiding all this time tha',
#  'nks he’s been avoiding all this time that we have been trying to put on him for ',
#  't we have been trying to put on him for two decades.  Alex Pappademas Yeah, he’l',
#  'two decades.  Alex Pappademas Yeah, he’ll be your mirror, right? If you’re like ',
#  'l be your mirror, right? If you’re like — it’s like, oh, you think of me as an A',
#  '— it’s like, oh, you think of me as an Asian-American actor? OK, I’m an Asian-Am',
#  'sian-American actor? OK, I’m an Asian-American actor then. It’s never occurred t',
#  'erican actor then. It’s never occurred to me before, but you’re right. I’m honor',
#  'o me before, but you’re right. I’m honored to be here in that cast, in that grou',
#  'ed to be here in that cast, in that group of people. You think of me as the inte',
#  'p of people. You think of me as the internet’s boyfriend? Oh, I will do that thi',
#  'rnet’s boyfriend? Oh, I will do that thing for you. I will be that.  He is alway',
#  'ng for you. I will be that.  He is always reflecting our own desires back to us.',
#  's reflecting our own desires back to us. It’s like there’s something about his u',
#  ' It’s like there’s something about his unknowability that makes that relationshi',
#  'nknowability that makes that relationship very personal, because we are seeing o',
#  'p very personal, because we are seeing ourselves every time we look at him. Our ',
#  'urselves every time we look at him. Our fandom for Keanu is participatory in a w',
#  'fandom for Keanu is participatory in a way that loving, say, Brad Pitt, is not. ',
#  'ay that loving, say, Brad Pitt, is not.  Wesley Morris OK, I want to take you ba',
#  ' Wesley Morris OK, I want to take you back to a “Matrix” moment.  Alex Pappadema',
#  'ck to a “Matrix” moment.  Alex Pappademas Yeah.  Wesley Morris Because I feel li',
#  's Yeah.  Wesley Morris Because I feel like many a Keanu movie has a Keanu metaph',
#  'ke many a Keanu movie has a Keanu metaphor in it. And the first thing you see in',
#  'or in it. And the first thing you see in the first scene of Neo/Thomas Anderson ',
#  ' the first scene of Neo/Thomas Anderson in his life at all in that apartment is ',
#  'in his life at all in that apartment is a computer screen. And it’s blinking, an',
#  'a computer screen. And it’s blinking, and the first word that you see is the wor',
#  'd the first word that you see is the word “searching” on a computer screen. And ',
#  'd “searching” on a computer screen. And it just really struck me that we are loo',
#  'it just really struck me that we are looking for something in him.  Archived Rec',
#  'king for something in him.  Archived Recording (Morpheus) I’ve been looking for ',
#  'ording (Morpheus) I’ve been looking for you, Neo.  Wesley Morris People in that ',
#  'you, Neo.  Wesley Morris People in that movie in “The Matrix” are looking for hi',
#  'movie in “The Matrix” are looking for him.  Archived Recording (Agent Smith) As ',
#  'm.  Archived Recording (Agent Smith) As you can see, we’ve had our eye on you fo',
#  'you can see, we’ve had our eye on you for some time now, Mr. Anderson.  Wesley M',
#  'r some time now, Mr. Anderson.  Wesley Morris He is plucked from a kind of obscu',
#  'orris He is plucked from a kind of obscurity and made to believe that he is a me',
#  'rity and made to believe that he is a messianic figure.  Archived Recording (Kea',
#  'ssianic figure.  Archived Recording (Keanu Reeves As Neo) What are you trying to',
#  'nu Reeves As Neo) What are you trying to tell me, that I can dodge bullets?  Arc',
#  ' tell me, that I can dodge bullets?  Archived Recording (Morpheus) No, Neo, I’m ',
#  'hived Recording (Morpheus) No, Neo, I’m trying to tell you that when you’re read',
#  'trying to tell you that when you’re ready, you won’t have to.  Wesley Morris And',
#  'y, you won’t have to.  Wesley Morris And he resists it.  Archived Recording (Kea',
#  ' he resists it.  Archived Recording (Keanu Reeves As Neo) I’m not the one.  Wesl',
#  'nu Reeves As Neo) I’m not the one.  Wesley Morris He doesn’t really believe this',
#  'ey Morris He doesn’t really believe this is true, but if you all want to believe',
#  ' is true, but if you all want to believe it, OK, I’ll do it.  Archived Recording',
#  ' it, OK, I’ll do it.  Archived Recording (Morpheus) We’re going in. We’re taking',
#  ' (Morpheus) We’re going in. We’re taking Neo to see her.  Archived Recording (Ke',
#  ' Neo to see her.  Archived Recording (Keanu Reeves As Neo) See who?  Archived Re',
#  'anu Reeves As Neo) See who?  Archived Recording (Crewmate) The Oracle.  Wesley M',
#  'cording (Crewmate) The Oracle.  Wesley Morris And I can’t think of another perso',
#  'orris And I can’t think of another person in any art form where so much of his v',
#  'n in any art form where so much of his value and his meaning comes down to us an',
#  'alue and his meaning comes down to us and our interpretation of it.  Alex Pappad',
#  'd our interpretation of it.  Alex Pappademas And I think it says a lot that in t',
#  'emas And I think it says a lot that in the fourth “Matrix,” basically, the momen',
#  'he fourth “Matrix,” basically, the moment comes when somebody shows up and is li',
#  't comes when somebody shows up and is like, Neo, you’ve got to come with us. We ',
#  'ke, Neo, you’ve got to come with us. We need you to go back into the Matrix and ',
#  'need you to go back into the Matrix and be Neo again. He’s like, OK. He’s just l',
#  'be Neo again. He’s like, OK. He’s just like, OK, man. He’s literally like, OK.  ',
#  'ike, OK, man. He’s literally like, OK.  I love that moment so much, because I th',
#  'I love that moment so much, because I think that the way that he is in that movi',
#  'ink that the way that he is in that movie versus the way that he is in the first',
#  'e versus the way that he is in the first “Matrix” movie says something about how',
#  ' “Matrix” movie says something about how he’s evolved in the interim, because he',
#  ' he’s evolved in the interim, because he’s made a peace with the idea of Keanu. ',
#  '’s made a peace with the idea of Keanu. And so when destiny calls, and they’re l',
#  'And so when destiny calls, and they’re like, come back to the Matrix, we need yo',
#  'ike, come back to the Matrix, we need you, he’s just right there. He goes along ',
#  'u, he’s just right there. He goes along with it. What was your question?  Wesley',
#  'with it. What was your question?  Wesley Morris There was no question. I just ma',
#  ' Morris There was no question. I just made a statement. And in some ways, I’m ju',
#  'de a statement. And in some ways, I’m just listening to you talk. And I’m remind',
#  'st listening to you talk. And I’m reminded of the thing that I think I have foun',
#  'ed of the thing that I think I have found appealing.  But if I were an actor, Al',
#  'd appealing.  But if I were an actor, Alex, I think Keanu Reeves is how I would ',
#  'ex, I think Keanu Reeves is how I would be caught acting. I wouldn’t be comforta',
#  'be caught acting. I wouldn’t be comfortable with the camera stuff. I wouldn’t be',
#  'ble with the camera stuff. I wouldn’t be comfortable having to pretend to be a d',
#  ' comfortable having to pretend to be a different person. I’d go along with a lot',
#  'ifferent person. I’d go along with a lot of it, but I wouldn’t really enjoy it. ',
#  ' of it, but I wouldn’t really enjoy it.  And the real truth of his presence on-s',
#  ' And the real truth of his presence on-screen is such an indictment of watching,',
#  'creen is such an indictment of watching, of looking at people perform anything. ',
#  ' of looking at people perform anything. It is getting at a fundamental awkwardne',
#  'It is getting at a fundamental awkwardness in the spectator-spectated relationsh',
#  'ss in the spectator-spectated relationship.  Alex Pappademas He’s looking at us ',
#  'ip.  Alex Pappademas He’s looking at us as much as we’re looking at him, I think',
#  'as much as we’re looking at him, I think. There’s a self-consciousness, but ther',
#  '. There’s a self-consciousness, but there is also an audience consciousness. He ',
#  'e is also an audience consciousness. He knows that we’re there, and he wonders i',
#  'knows that we’re there, and he wonders if we’ve figured out that it’s just Keanu',
#  'f we’ve figured out that it’s just Keanu Reeves once again playing a character, ',
#  ' Reeves once again playing a character, that we have not forgotten that it’s him',
#  'that we have not forgotten that it’s him. Is that good acting?  Wesley Morris If',
#  '. Is that good acting?  Wesley Morris If nothing else, Alex, it is definitely, d',
#  ' nothing else, Alex, it is definitely, definitely great Keanu-ing.  Alex Pappade',
#  'efinitely great Keanu-ing.  Alex Pappademas There might be no other comparisons.',
#  'mas There might be no other comparisons.  Wesley Morris No, that’s it. There’s o',
#  '  Wesley Morris No, that’s it. There’s only one Keanu.  Alex Pappademas One of o',
#  'nly one Keanu.  Alex Pappademas One of one.  [MUSIC]  Wesley Morris Alex Pappade',
#  'ne.  [MUSIC]  Wesley Morris Alex Pappademas, I love you. Thanks for coming on th',
#  'mas, I love you. Thanks for coming on the show.  Alex Pappademas I love you too,',
#  'e show.  Alex Pappademas I love you too, man, and any time you want to talk for ',
#  ' man, and any time you want to talk for 17 hours about Keanu, you know where to ',
#  '17 hours about Keanu, you know where to find me.  Wesley Morris I do. I actually',
#  'find me.  Wesley Morris I do. I actually do.  That’s our show. Alex Pappademas’s',
#  ' do.  That’s our show. Alex Pappademas’s book, “Keanu Reeves: Most Triumphant: T',
#  ' book, “Keanu Reeves: Most Triumphant: The Movies and Meaning of an Irrepressibl',
#  'he Movies and Meaning of an Irrepressible Icon” is out. Now run to the bookstore',
#  'e Icon” is out. Now run to the bookstore.  He’s also host of the excellent podca',
#  '.  He’s also host of the excellent podcast, “The Big Hit Show.” “Still Processin',
#  'st, “The Big Hit Show.” “Still Processing” is produced by Elyssa Dudley and Hans',
#  'g” is produced by Elyssa Dudley and Hans Buetow. It’s edited by Sara Sarasohn an',
#  ' Buetow. It’s edited by Sara Sarasohn and Sasha Weiss. The show is mixed by Mari',
#  'd Sasha Weiss. The show is mixed by Marion Lozano and recorded by Maddy Masiello',
#  'on Lozano and recorded by Maddy Masiello, digital production by Mahima Chablani ',
#  ', digital production by Mahima Chablani and Des Ibekwe. Our theme music is by Ki',
#  'and Des Ibekwe. Our theme music is by Kindness. It’s called “World Restart” from',
#  'ndness. It’s called “World Restart” from the album, “Otherness.” And we will be ',
#  ' the album, “Otherness.” And we will be back next week. Thanks for listening. ']

# %%
shingle(windows(cleaned)[0])
# Out:
# {' a di',
#  ' diff',
#  ' kian',
#  ' kind',
#  ' of r',
#  ' rock',
#  ' star',
#  ' to',
#  ' was ',
#  "'s a ",
#  'a dif',
#  "anoo'",
#  'ar ki',
#  'ar to',
#  'as a ',
#  'ck st',
#  'd of ',
#  'diffe',
#  'ent k',
#  'erent',
#  'f roc',
#  'feren',
#  'ffere',
#  'ianoo',
#  'iffer',
#  'ind o',
#  'k sta',
#  'kiano',
#  'kind ',
#  'kurt ',
#  'nd of',
#  "noo's",
#  'nt ki',
#  'o',
#  "o's a",
#  'ock s',
#  'of ro',
#  "oo's ",
#  'r kia',
#  'r to',
#  'rent ',
#  'rock ',
#  'rt wa',
#  's a d',
#  'star ',
#  't kin',
#  't was',
#  'tar k',
#  'tar t',
#  'to',
#  'urt w',
#  'was a'}

# %%
def windows(text: str, n_chars=80) -> typing.List[str]:
    n = int(2 * len(text) / n_chars)
    def offset(i):
        return int(i * n_chars / 2)
    return [
        text[offset(i):(offset(i)+n_chars)] for i in range(n)
    ]
    
def shingle(text: str, k = 5):
    return {text[i:i+k] for i in range(len(text))}

def jaquard(a: set, b: set) -> float:
    return len(a.intersection(b)) / len(a.union(b))

def similarity(queries, candidates):
    for i, query in enumerate(queries):
        for j, candidate in enumerate(candidates):
            if jaquard(shingle(query), shingle(candidate)) > 0.4:
                print(i, j)
                print("Q: ", query)
                print("X: ", candidate)
                
similarity(windows(cleaned), windows(ys[0].lower()))
# Out:
# 1 239
# Q:  ianoo's a different kind of rock star too andhe has a lot of big hits he has spe
# X:  different kind of rock star too. and he has a lot of big hits. he has “speed,” w
# 6 245
# Q:  s an action starthenhe runs in the other directioit is a very genex thing to do
# X:  then he runs in the other direction. it is a very gen x thing to do when confron
# 7 246
# Q:   directioit is a very genex thing to do when confronted with the opportunity to
# X:  is a very gen x thing to do when confronted with the opportunity to be super fam
# 8 247
# Q:  when confronted with the opportunity to be superfamous hdoes hamlet canadaand he
# X:  ted with the opportunity to be super famous. and he does hamlet in canada. and h

# %%
ys[0]
# Out:
# 'Wesley Morris Alex Pappademas, you’ve written a book.  Alex Pappademas Yeah, how about that?  Wesley Morris It’s called “Keanu Reeves: Most Triumphant: The Movies and Meaning of an Irrepressible Icon.”  But I have a question for you. Is it possible to even get near the bottom of Keanu Reeves?  Alex Pappademas I think he might be an unknowable icon. I sit before you as someone who’s thought about him for a whole year, and I don’t know if I know him any better than you do. But let’s find out.  Wesley Morris Here we go.  [MUSIC]  I’m Wesley Morris, and I’m a culture writer at The New York Times, and this is “Still Processing.” Today on the show, we’re going to talk about the one, the only, Keanu Reeves, and we’re going to try and figure out why we get so much out of a movie star who appears to give us so little.  Alex, I think I have what is probably a pretty common Keanu Reeves experience, which is that I kind of took him for granted. He’s always been in my life, and I just never really felt like there was much to figure out. But who is this person, and what have I been misunderstanding if I’m thinking of him as an empty vessel?  Alex Pappademas Maybe he’s an empty vessel, and that’s a possibility that we have to entertain as part of it, I think. And I think part of your feeling that you can’t look right at him, and that he doesn’t — it’s almost like your interest glances off of him, I think it’s a valid Keanu experience.  And I think that a lot of that gets dramatized in the work. He is always that guy who comes into the story and needs to be filled up. And what’s the most obvious metaphorical version of that?  Archived Recording (Morpheus) The Matrix is everywhere. It is all around us.  Alex Pappademas He has to get a plug put in the back of his head, and he gets filled up with kung fu just right in the back of the head.  Archived Recording (Keanu Reeves As Neo) I know kung fu.  Archived Recording (Morpheus) Show me.  Alex Pappademas And I feel like that’s part of the thing that you are watching with Keanu, is somebody who comes into a story with nothing and has to get filled up with ideas. And I think what I’m chasing after in this book is those moments when the movie gets so thin that you can basically see right through it, and you just see Keanu — and the movie is revealed as an artifice that Keanu is doing something real within it.  Archived Recording (Morpheus) What is real? How do you define real?  Wesley Morris Well, I want to go back to 1991, which is about eight years before “The Matrix” comes out. It was the year of “Point Break,” the year of “My Own Private Idaho” — two very, very different movies that use him in not dissimilar ways, right?  Alex Pappademas Yeah, because there’s three movies in ‘91. It’s the best movie year an actor has ever had, because there’s also “Bill and Ted’s Bogus Journey.”  Archived Recording (Bill And Ted) How’s it going, Bill and Ted?  Archived Recording (Ted) We came to help you guys in your most unfortunate situation.  Archived Recording (Bill) Yeah.  Alex Pappademas Each of them — “Bogus Journey,” “Point Break,” “My Own Private Idaho,” each one like a platonic love story between two guys.  Archived Recording (Patrick Swayze As Bodhi) You still haven’t figured out what riding waves is all about, have you? It’s a state of mind.  Wesley Morris And for anybody who doesn’t know, “Point Break” is, of course, the “surfers rob a bank” movie starring Keanu Reeves as an F.B.I. agent —  Archived Recording (Ben Harp) Special Agent Utah, are you receiving my signal?  Archived Recording (Keanu Reeves As Johnny Utah) Zero distortion, sir.  Wesley Morris — and Patrick Swayze as the head of the bank robbing crew.  Archived Recording (Bodhi) You want the ultimate, you got to be willing to pay the ultimate price.  Wesley Morris So what’s going on with Keanu in this movie as far as you can see? Because I have to tell you something, Alex. I still haven’t seen it.  Alex Pappademas For starters, “Point Brea ...
