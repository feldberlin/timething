# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %cd ../src
# Out:
# /Users/ranykeddo/src/github.com/feldberlin/timething/src

# %%
from dataclasses import replace
from pathlib import Path
import time

import torch
import torchaudio
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd
from tqdm import tqdm  # type: ignore

from timething import dataset, job, text, utils, align, viz

# %% [markdown]
# # Process 30 minutes of audio
#
# ## Simple concatenation strategy
# We will split the original audio into 5 second chunks. Each chunk is passed through the model. The resulting logits are concatenated into a single tensor. Alignment is a single pass over the concatenated logits.

# %% [markdown]
# ## Setup

# %%
# basic config
device = "cpu"
resample_to = 16000
batch_size = 40
seconds_per_sample = 5
hopsize_seconds = seconds_per_sample
cfg = utils.load_config("english")

# data
fixtures_path = Path("../fixtures")
keanu_audio = fixtures_path / "audio" / "keanu.mp3"
with open(fixtures_path / "keanu.cleaned.txt", "r") as f:
    keanu_transcript = f.read()
    keanu_transcript = " ".join(keanu_transcript.lower().splitlines())

# %%
# initialize dataset
ds = dataset.WindowedTrackDataset(
    keanu_audio, 
    "mp3", 
    keanu_transcript,
    seconds_per_sample * 1000, 
    hopsize_seconds * 1000, 
    resample_to=resample_to
)

print(f"dataset length: { len(ds) }")

# initialize job
j = job.LongTrackJob(
    cfg,
    ds,
    batch_size=1,
    n_workers=1,
)
# Out:
# dataset length: 313
# /Users/ranykeddo/anaconda3/envs/timething/lib/python3.8/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")

# %% [markdown]
# We have set hopsize to the sample length. So we just wind up cutting up the original into chunks, no overlap. Let's validate that we can put the audio back together as expected:

# %% [markdown]
# ### Audio

# %%
display(ipd.Audio(torch.concat([ds[i].audio.squeeze() for i in range(5)]), rate=resample_to))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Transcription

# %%
print(f"ORIGINAL: { keanu_transcript[:880] }\n")
print(f"CLEANED: { ds.clean_text_fn(keanu_transcript)[:880] }")
# Out:
# ORIGINAL: alex pappademas, you’ve written a book. yeah, how about that? it’s called “keanu reeves: most triumphant: the movies and meaning of an irrepressible icon.” but i have a question for you. is it possible to even get near the bottom of keanu reeves? i think he might be an unknowable icon. i sit before you as someone who’s thought about him for a whole year, and i don’t know if i know him any better than you do. but let’s find out. here we go. i’m a culture writer at the new york times, and this is “still processing.” today on the show, we’re going to talk about the one, the only, keanu reeves, and we’re going to try and figure out why we get so much out of a movie star who appears to give us so little. i think i have what is probably a pretty common keanu reeves experience, which is that i kind of took him for granted. he’s always been in my life, and i just never really
#
# CLEANED: alex|pappademas|you|ve|written|a|book|yeah|how|about|that|it|s|called|keanu|reeves|most|triumphant|the|movies|and|meaning|of|an|irrepressible|icon|but|i|have|a|question|for|you|is|it|possible|to|even|get|near|the|bottom|of|keanu|reeves|i|think|he|might|be|an|unknowable|icon|i|sit|before|you|as|someone|who|s|thought|about|him|for|a|whole|year|and|i|don|t|know|if|i|know|him|any|better|than|you|do|but|let|s|find|out|here|we|go|i|m|a|culture|writer|at|the|new|york|times|and|this|is|still|processing|today|on|the|show|we|re|going|to|talk|about|the|one|the|only|keanu|reeves|and|we|re|going|to|try|and|figure|out|why|we|get|so|much|out|of|a|movie|star|who|appears|to|give|us|so|little|i|think|i|have|what|is|probably|a|pretty|common|keanu|reeves|experience|which|is|that|i|kind|of|took|him|for|granted|he|s|always|been|in|my|life|and|i|just|never|really|felt|like|there|was|much|to

# %% [markdown]
# ## Chunked alignment
#
# We will loop over the 5 second chunks, feed them through the model and save the resulting logits in a list. Will will perform alignment on the concatenated logits.

# %%
alignments = j.run()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 313/313 [01:45<00:00,  2.96it/s]
# aligning...

# %% [markdown]
# ### Recognition results
#
# Let's take a look at the logits by decoding the text using a simple argmax strategy:

# %%
recognized = text.decode_best(alignments.log_probs.squeeze(), j.aligner.dictionary)
recognized = text.ctc_collapse(recognized)
recognized[:1000]
# Out:
# "alex papademus you've written the book yea how about thatit's  kiaariv's most triumphant the movies and meeting of an aror pes sible iconbut i have a question for you is it possible l o even get near the bottom of ceonerweavesi think he might  y an unknowable iconsit before you someone who's thought about him for e a whole year and i dont know if i know him any better than you do but let's find out  we go i'm wesley morris and i'm a culture writer at the new york times and this is still processing tettin on the show worege a talk about the one the only ceonter weaves and we're gon ta trine figure out swhy we get so much out of a movie star who appears to give us  te te e alex i think i have woit tis probably a pretty common keonarives experiencewhich is  ikano took him for granted he's always been in my life i just never really felt like here was much to figure outbut who is this person and what have i been misunderstanding if i'm thinking of im as an empty vessel i mean maybe he's an "

# %% [markdown]
# ### Alignment results

# %%
words = alignments.words_cleaned
words[:50]
# Out:
# [Segment(label='alex', start=24, end=36, score=0.9984560929811918),
#  Segment(label='pappademas', start=37, end=67, score=0.9262847508111134),
#  Segment(label='you', start=95, end=98, score=0.6182636597659439),
#  Segment(label='ve', start=100, end=102, score=0.9942612846692404),
#  Segment(label='written', start=103, end=111, score=0.8213972086933526),
#  Segment(label='a', start=114, end=116, score=0.3580108418439825),
#  Segment(label='book', start=117, end=128, score=0.9544141190126538),
#  Segment(label='yeah', start=149, end=163, score=0.7664356473687803),
#  Segment(label='how', start=165, end=172, score=0.7130837318513336),
#  Segment(label='about', start=174, end=185, score=0.9208486336462486),
#  Segment(label='that', start=187, end=198, score=0.9582076809908214),
#  Segment(label='it', start=225, end=228, score=0.6177497905271594),
#  Segment(label='s', start=230, end=231, score=0.9076717694600424),
#  Segment(label='called', start=233, end=247, score=0.8369190668933751),
#  Segment(label='keanu', start=267, end=284, score=0.724047536670696),
#  Segment(label='reeves', start=285, end=299, score=0.6920685486402363),
#  Segment(label='most', start=301, end=310, score=0.9217269948937676),
#  Segment(label='triumphant', start=312, end=339, score=0.9902542519072691),
#  Segment(label='the', start=384, end=389, score=0.9828789085149765),
#  Segment(label='movies', start=392, end=417, score=0.9958250215559294),
#  Segment(label='and', start=425, end=430, score=0.8154486999846995),
#  Segment(label='meaning', start=433, end=454, score=0.9059764178527985),
#  Segment(label='of', start=465, end=469, score=0.7023512667843274),
#  Segment(label='an', start=472, end=474, score=0.7609611272811889),
#  Segment(label='irrepressible', start=477, end=509, score=0.6986664620879408),
#  Segment(label='icon', start=514, end=586, score=0.9856918381482414),
#  Segment(label='but', start=587, end=591, score=0.694405801439037),
#  Segment(label='i', start=593, end=594, score=0.985519677400589),
#  Segment(label='have', start=595, end=600, score=0.8317254174811145),
#  Segment(label='a', start=601, end=602, score=0.9650600552558899),
#  Segment(label='question', start=604, end=620, score=0.8259089826126856),
#  Segment(label='for', start=621, end=626, score=0.913019380399159),
#  Segment(label='you', start=628, end=639, score=0.9534479148494892),
#  Segment(label='is', start=706, end=710, score=0.8930182059605917),
#  Segment(label='it', start=712, end=717, score=0.9768913047654288),
#  Segment(label='possible', start=719, end=745, score=0.9554029436487901),
#  Segment(label='to', start=757, end=762, score=0.851932322437113),
#  Segment(label='even', start=768, end=777, score=0.9889954762025313),
#  Segment(label='get', start=779, end=789, score=0.9959298148751259),
#  Segment(label='near', start=795, end=817, score=0.961123993396759),
#  Segment(label='the', start=820, end=825, score=0.9823917746543884),
#  Segment(label='bottom', start=827, end=846, score=0.9831764999222248),
#  Segment(label='of', start=874, end=881, score=0.5757696997579842),
#  Segment(label='keanu', start=883, end=902, score=0.6746791942998589),
#  Segment(label='reeves', start=904, end=961, score=0.9510308159374761),
#  Segment(label='i', start=962, end=964, score=0.7341448394581676),
#  Segment(label='think', start=966, end=973, score=0.7870800429955125),
#  Segment(label='he', start=975, end=980, score=0.8995880335569382),
#  Segment(label='might', start=983, end=994, score=0.8260784683128198),
#  Segment(label='be', start=995, end=999, score=0.5397817373275757)]

# %%
audio, audio_sr = torchaudio.load(keanu_audio)
logits_sr = alignments.log_probs[0].size(1) / (ds.window_size_ms / 1000)

def audio_segment(s):
    start = int(s.start / logits_sr * audio_sr)
    end = int(s.end / logits_sr * audio_sr)
    return audio[:, start:end]

def audio_segments(s):
    start = int(s[0].start / logits_sr * audio_sr)
    end = int(s[-1].end / logits_sr * audio_sr)
    return audio[:, start:end]

def show(word):
    print(word)
    display(ipd.Audio(audio_segment(word), rate=audio_sr))

def show_all(words):
    print(" ".join([w.label for w in words]))
    display(ipd.Audio(audio_segments(words), rate=audio_sr))

# %%
print("some words\n========\n")
show(words[0])
show(words[100])
# Out:
# some words
# ========
#
# Segment(label='alex', start=24, end=36, score=0.9984560929811918)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Segment(label='and', start=1966, end=1990, score=0.9995575802666801)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Analysis
#
# The alignment appears to have worked very well. I would have expected boundary artefacts to reduce quality every 5 seconds. When would this be true? It would be true when the alignment takes a different path, e.g we repeat letters for too long or too short, or we switch to the next letter to late or too early. Let's take a look

# %%
# let's pick out the frame start and end numbers on the 5 second boundaries
boundaries = [i * 5 for i in range(1, 5 * 60)]  # boundaries
boundaries = [(int(logits_sr * (i - 1)), int(logits_sr * (i + 1))) for i in boundaries]  # converted to logit frequency

# pick out the words that span those boundaries
i = 0
results = {}
for start, end in boundaries:
    segments = []
    while i < len(words):
        if not segments and words[i].start > start:
            segments.append(words[i - 1])
        elif segments and words[i].end > end:
            segments.append(words[i - 1])
            segments.append(words[i])
            results[(start, end)] = segments
            segments = []
            break
        elif segments:
            segments.append(words[i - 1])
        i += 1

# play
i = 0
for k, words in results.items():
    if i > 50:
        break
    print()
    print(k)
    for w in words:
        print(w)
    i += 1
# Out:
# (26, 39)
# Segment(label='alex', start=24, end=36, score=0.9984560929811918)
# Segment(label='pappademas', start=37, end=67, score=0.9262847508111134)
# Segment(label='you', start=95, end=98, score=0.6182636597659439)
#
# (59, 72)
# Segment(label='pappademas', start=37, end=67, score=0.9262847508111134)
# Segment(label='you', start=95, end=98, score=0.6182636597659439)
# Segment(label='ve', start=100, end=102, score=0.9942612846692404)
#
# (92, 105)
# Segment(label='you', start=95, end=98, score=0.6182636597659439)
# Segment(label='ve', start=100, end=102, score=0.9942612846692404)
# Segment(label='written', start=103, end=111, score=0.8213972086933526)
#
# (125, 138)
# Segment(label='book', start=117, end=128, score=0.9544141190126538)
# Segment(label='yeah', start=149, end=163, score=0.7664356473687803)
# Segment(label='how', start=165, end=172, score=0.7130837318513336)
#
# (158, 171)
# Segment(label='yeah', start=149, end=163, score=0.7664356473687803)
# Segment(label='how', start=165, end=172, score=0.7130837318513336)
# Segment(label='about', start=174, end=185, score=0.9208486336462486)
#
# (191, 204)
# Segment(label='that', start=187, end=198, score=0.9582076809908214)
# Segment(label='it', start=225, end=228, score=0.6177497905271594)
# Segment(label='s', start=230, end=231, score=0.9076717694600424)
#
# (224, 237)
# Segment(label='it', start=225, end=228, score=0.6177497905271594)
# Segment(label='s', start=230, end=231, score=0.9076717694600424)
# Segment(label='called', start=233, end=247, score=0.8369190668933751)
#
# (257, 270)
# Segment(label='called', start=233, end=247, score=0.8369190668933751)
# Segment(label='keanu', start=267, end=284, score=0.724047536670696)
# Segment(label='reeves', start=285, end=299, score=0.6920685486402363)
#
# (290, 303)
# Segment(label='reeves', start=285, end=299, score=0.6920685486402363)
# Segment(label='most', start=301, end=310, score=0.9217269948937676)
# Segment(label='triumphant', start=312, end=339, score=0.9902542519072691)
#
# (323, 336)
# Segment(label='triumphant', start=312, end=339, score=0.9902542519072691)
# Segment(label='the', start=384, end=389, score=0.9828789085149765)
# Segment(label='movies', start=392, end=417, score=0.9958250215559294)
#
# (356, 369)
# Segment(label='the', start=384, end=389, score=0.9828789085149765)
# Segment(label='movies', start=392, end=417, score=0.9958250215559294)
# Segment(label='and', start=425, end=430, score=0.8154486999846995)
#
# (389, 402)
# Segment(label='movies', start=392, end=417, score=0.9958250215559294)
# Segment(label='and', start=425, end=430, score=0.8154486999846995)
# Segment(label='meaning', start=433, end=454, score=0.9059764178527985)
#
# (422, 435)
# Segment(label='and', start=425, end=430, score=0.8154486999846995)
# Segment(label='meaning', start=433, end=454, score=0.9059764178527985)
# Segment(label='of', start=465, end=469, score=0.7023512667843274)
#
# (455, 468)
# Segment(label='meaning', start=433, end=454, score=0.9059764178527985)
# Segment(label='of', start=465, end=469, score=0.7023512667843274)
# Segment(label='an', start=472, end=474, score=0.7609611272811889)
#
# (488, 501)
# Segment(label='irrepressible', start=477, end=509, score=0.6986664620879408)
# Segment(label='icon', start=514, end=586, score=0.9856918381482414)
# Segment(label='but', start=587, end=591, score=0.694405801439037)
#
# (521, 534)
# Segment(label='icon', start=514, end=586, score=0.9856918381482414)
# Segment(label='but', start=587, end=591, score=0.694405801439037)
# Segment(label='i', start=593, end=594, score=0.985519677400589)
#
# (554, 567)
# Segment(label='but', start=587, end=591, score=0.694405801439037)
# Segment(label='i', start=593, end=594, score=0.985519677400589)
# Segment(label='have', start=595, end=600, score=0.8317254174811145)
#
# (587, 600)
# Segment(label='i', start=593, end=594, score=0.985519677400589)
# Segment(label='have', start=595, end=600, score=0.8317254174811145)
# Segment(label='a', start=601, end=602, score=0.9650600552558899)
#
# (620, 633)
# Segment(label='question', start=604, end=620, score=0.8259089826126856)
# Segment(label='for', start=621, end=626, score=0.913019380399159)
# Segment(label='you', start=628, end=639, score=0.9534479148494892)
#
# (653, 666)
# Segment(label='you', start=628, end=639, score=0.9534479148494892)
# Segment(label='is', start=706, end=710, score=0.8930182059605917)
# Segment(label='it', start=712, end=717, score=0.9768913047654288)
#
# (686, 699)
# Segment(label='is', start=706, end=710, score=0.8930182059605917)
# Segment(label='it', start=712, end=717, score=0.9768913047654288)
# Segment(label='possible', start=719, end=745, score=0.9554029436487901)
#
# (719, 732)
# Segment(label='possible', start=719, end=745, score=0.9554029436487901)
# Segment(label='to', start=757, end=762, score=0.851932322437113)
# Segment(label='even', start=768, end=777, score=0.9889954762025313)
#
# (752, 765)
# Segment(label='to', start=757, end=762, score=0.851932322437113)
# Segment(label='even', start=768, end=777, score=0.9889954762025313)
# Segment(label='get', start=779, end=789, score=0.9959298148751259)
#
# (785, 798)
# Segment(label='get', start=779, end=789, score=0.9959298148751259)
# Segment(label='near', start=795, end=817, score=0.961123993396759)
# Segment(label='the', start=820, end=825, score=0.9823917746543884)
#
# (818, 831)
# Segment(label='near', start=795, end=817, score=0.961123993396759)
# Segment(label='the', start=820, end=825, score=0.9823917746543884)
# Segment(label='bottom', start=827, end=846, score=0.9831764999222248)
#
# (851, 864)
# Segment(label='bottom', start=827, end=846, score=0.9831764999222248)
# Segment(label='of', start=874, end=881, score=0.5757696997579842)
# Segment(label='keanu', start=883, end=902, score=0.6746791942998589)
#
# (884, 897)
# Segment(label='keanu', start=883, end=902, score=0.6746791942998589)
# Segment(label='reeves', start=904, end=961, score=0.9510308159374761)
# Segment(label='i', start=962, end=964, score=0.7341448394581676)
#
# (917, 930)
# Segment(label='reeves', start=904, end=961, score=0.9510308159374761)
# Segment(label='i', start=962, end=964, score=0.7341448394581676)
# Segment(label='think', start=966, end=973, score=0.7870800429955125)
#
# (950, 963)
# Segment(label='i', start=962, end=964, score=0.7341448394581676)
# Segment(label='think', start=966, end=973, score=0.7870800429955125)
# Segment(label='he', start=975, end=980, score=0.8995880335569382)
#
# (983, 996)
# Segment(label='might', start=983, end=994, score=0.8260784683128198)
# Segment(label='be', start=995, end=999, score=0.5397817373275757)
# Segment(label='an', start=1000, end=1004, score=0.8594477110438876)
#
# (1016, 1029)
# Segment(label='unknowable', start=1009, end=1032, score=0.9552125725252875)
# Segment(label='icon', start=1038, end=1053, score=0.9844284404496677)
# Segment(label='i', start=1099, end=1102, score=0.7491652131080627)
#
# (1049, 1062)
# Segment(label='icon', start=1038, end=1053, score=0.9844284404496677)
# Segment(label='i', start=1099, end=1102, score=0.7491652131080627)
# Segment(label='sit', start=1104, end=1113, score=0.8061138480901718)
#
# (1082, 1095)
# Segment(label='i', start=1099, end=1102, score=0.7491652131080627)
# Segment(label='sit', start=1104, end=1113, score=0.8061138480901718)
# Segment(label='before', start=1114, end=1128, score=0.8846940577030182)
#
# (1115, 1128)
# Segment(label='before', start=1114, end=1128, score=0.8846940577030182)
# Segment(label='you', start=1129, end=1134, score=0.8658075332641602)
# Segment(label='as', start=1135, end=1137, score=0.0116193941309272)
#
# (1148, 1161)
# Segment(label='someone', start=1138, end=1149, score=0.8302711274203224)
# Segment(label='who', start=1150, end=1155, score=0.6841363011238476)
# Segment(label='s', start=1156, end=1159, score=0.6379289720207453)
# Segment(label='thought', start=1160, end=1169, score=0.7606918959751386)
#
# (1181, 1194)
# Segment(label='him', start=1180, end=1186, score=0.9461572037802802)
# Segment(label='for', start=1189, end=1207, score=0.7801107081927752)
# Segment(label='a', start=1208, end=1209, score=0.7996075550715128)
#
# (1214, 1227)
# Segment(label='whole', start=1211, end=1221, score=0.827131452402682)
# Segment(label='year', start=1223, end=1243, score=0.940420067006791)
# Segment(label='and', start=1250, end=1258, score=0.978850245475769)
#
# (1247, 1260)
# Segment(label='year', start=1223, end=1243, score=0.940420067006791)
# Segment(label='and', start=1250, end=1258, score=0.978850245475769)
# Segment(label='i', start=1277, end=1279, score=0.993021031220754)
#
# (1280, 1293)
# Segment(label='don', start=1280, end=1286, score=0.781308768094667)
# Segment(label='t', start=1287, end=1288, score=0.5025921983469743)
# Segment(label='know', start=1291, end=1299, score=0.836381914652884)
#
# (1313, 1326)
# Segment(label='if', start=1301, end=1305, score=0.9045979464426637)
# Segment(label='i', start=1317, end=1320, score=0.8005863264203071)
# Segment(label='know', start=1322, end=1330, score=0.7483492692408618)
#
# (1346, 1359)
# Segment(label='him', start=1332, end=1341, score=0.9507947929863197)
# Segment(label='any', start=1356, end=1364, score=0.9992221593856812)
# Segment(label='better', start=1365, end=1375, score=0.9828477935357527)
#
# (1379, 1392)
# Segment(label='than', start=1376, end=1381, score=0.7638428644983962)
# Segment(label='you', start=1383, end=1388, score=0.7020882839957873)
# Segment(label='do', start=1389, end=1396, score=0.9618902206420898)
#
# (1412, 1425)
# Segment(label='do', start=1389, end=1396, score=0.9618902206420898)
# Segment(label='but', start=1418, end=1428, score=0.9692552405245164)
# Segment(label='let', start=1435, end=1441, score=0.6980214577779407)
#
# (1445, 1458)
# Segment(label='find', start=1445, end=1452, score=0.8039639400905633)
# Segment(label='out', start=1456, end=1492, score=0.9612675777230507)
# Segment(label='here', start=1495, end=1781, score=0.9665697393432345)
#
# (1478, 1491)
# Segment(label='out', start=1456, end=1492, score=0.9612675777230507)
# Segment(label='here', start=1495, end=1781, score=0.9665697393432345)
# Segment(label='we', start=1783, end=1801, score=0.7785772635749445)
#
# (1511, 1524)
# Segment(label='here', start=1495, end=1781, score=0.9665697393432345)
# Segment(label='we', start=1783, end=1801, score=0.7785772635749445)
# Segment(label='go', start=1802, end=1822, score=0.6940698112997884)
#
# (1544, 1557)
# Segment(label='we', start=1783, end=1801, score=0.7785772635749445)
# Segment(label='go', start=1802, end=1822, score=0.6940698112997884)
# Segment(label='i', start=1838, end=1840, score=0.5308489687740803)
#
# (1577, 1590)
# Segment(label='go', start=1802, end=1822, score=0.6940698112997884)
# Segment(label='i', start=1838, end=1840, score=0.5308489687740803)
# Segment(label='m', start=1842, end=1845, score=0.5999219798010017)
#
# (1610, 1623)
# Segment(label='i', start=1838, end=1840, score=0.5308489687740803)
# Segment(label='m', start=1842, end=1845, score=0.5999219798010017)
# Segment(label='a', start=1847, end=1848, score=0.9951807260513306)
#
# (1643, 1656)
# Segment(label='m', start=1842, end=1845, score=0.5999219798010017)
# Segment(label='a', start=1847, end=1848, score=0.9951807260513306)
# Segment(label='culture', start=1849, end=1865, score=0.8459725553790728)
#
# (1676, 1689)
# Segment(label='a', start=1847, end=1848, score=0.9951807260513306)
# Segment(label='culture', start=1849, end=1865, score=0.8459725553790728)
# Segment(label='writer', start=1867, end=1880, score=0.9135888908058405)
